# %% [markdown]
# <a href="https://colab.research.google.com/github/reshmicoding/My-Portfolio-Projects/blob/main/home_credit_risk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall -y kaggle
# !pip install -U kaggle -q
# Out:
# Found existing installation: kaggle 2.0.2
# Uninstalling kaggle-2.0.2:
#   Successfully uninstalled kaggle-2.0.2
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.2/229.2 kB 14.2 MB/s eta 0:00:00

# %%
from google.colab import userdata

import os
os.environ["KAGGLE_API_TOKEN"] = userdata.get('KAGGLE_API_TOKEN')

# %%
# !kaggle datasets list -s "home credit default risk"
# Out:
# ref                                                  title                                             size  lastUpdated                 downloadCount  voteCount  usabilityRating
# ---------------------------------------------------  ------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# willkoehrsen/home-credit-default-risk-feature-tools  Home Credit Default Risk Feature Tools      3902091882  2018-08-16 19:12:18.250000           3351         53  0.4117647
# laotse/credit-risk-dataset                           Credit Risk Dataset                             376518  2020-06-02 06:10:39.067000          63365        345  0.7058824
# rikdifos/credit-card-approval-prediction             Credit Card Approval Prediction                5578875  2020-03-24 10:04:48.753000         100468        928  1
# ...

# %%
# !kaggle datasets download -d megancrenshaw/home-credit-default-risk -p data/
# Out:
# Dataset URL: https://www.kaggle.com/datasets/megancrenshaw/home-credit-default-risk
# License(s): unknown
# ...
# 100% 688M/688M [00:11<00:00, 63.8MB/s]

# %%
# !unzip data/home-credit-default-risk.zip -d data/
# Out:
# Archive:  data/home-credit-default-risk.zip
#   inflating: data/HomeCredit_columns_description.csv
#   inflating: data/POS_CASH_balance.csv
#   inflating: data/bureau.csv
#   inflating: data/bureau_balance.csv
#   inflating: data/credit_card_balance.csv
#   inflating: data/home-credit-default-risk/HomeCredit_columns_description.csv
#   inflating: data/home-credit-default-risk/application_test.csv
#   inflating: data/home-credit-default-risk/application_train.csv
#   inflating: data/home-credit-default-risk/sample_submission.csv
#   inflating: data/installments_payments.csv
#   inflating: data/previous_application.csv

# %%
import pandas as pd
df = pd.read_csv("data/HomeCredit_columns_description.csv", encoding='latin1')
df.head()
# Out:
#    Unnamed: 0                         Table                 Row  \
# 0           1  application_{train|test}.csv          SK_ID_CURR
# 1           2  application_{train|test}.csv              TARGET
# 2           5  application_{train|test}.csv  NAME_CONTRACT_TYPE
# 3           6  application_{train|test}.csv         CODE_GENDER
# 4           7  application_{train|test}.csv        FLAG_OWN_CAR
#
#                                          Description Special
# 0                           ID of loan in our sample     NaN
# 1  Target variable (1 - client with payment diffi...     NaN
# 2        Identification if loan is cash or revolving     NaN
# 3                               Gender of the client     NaN
# 4                      Flag if the client owns a car     NaN
